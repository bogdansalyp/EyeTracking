# %%
# !pip3 install mtcnn
# Out:
# Collecting mtcnn
#   Using cached https://files.pythonhosted.org/packages/67/43/abee91792797c609c1bf30f1112117f7a87a713ebaa6ec5201d5555a73ef/mtcnn-0.1.0-py3-none-any.whl
# Requirement already satisfied: keras>=2.0.0 in /usr/local/lib/python3.7/site-packages (from mtcnn) (2.2.4)
# Requirement already satisfied: opencv-python>=4.1.0 in /usr/local/lib/python3.7/site-packages (from mtcnn) (4.1.0.25)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.7/site-packages (from keras>=2.0.0->mtcnn) (1.2.1)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.7/site-packages (from keras>=2.0.0->mtcnn) (1.16.2)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.7/site-packages (from keras>=2.0.0->mtcnn) (1.0.9)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/site-packages (from keras>=2.0.0->mtcnn) (2.9.0)
# Requirement already satisfied: keras-applications>=1.0.6 in /usr/local/lib/python3.7/site-packages (from keras>=2.0.0->mtcnn) (1.0.7)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.7/site-packages (from keras>=2.0.0->mtcnn) (1.12.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/site-packages (from keras>=2.0.0->mtcnn) (5.1)
# Installing collected packages: mtcnn
# Successfully installed mtcnn-0.1.0

# %%
from mtcnn import MTCNN
import matplotlib.pyplot as plt

# %%
pixels = plt.imread('../sample_images/sample.jpg')

# %%
plt.imshow(pixels)

# %%
# create the detector, using default weights
detector = MTCNN()
# detect faces in the image
results = detector.detect_faces(pixels)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
# extract the bounding box from the first face
x1, y1, width, height = results[0]['box']
x2, y2 = x1 + width, y1 + height

# %%
# extract the face
face = pixels[y1:y2, x1:x2]

# %%
plt.imshow(face)
